# %% [markdown]
# ### Pandas Series
# #### A Series is a one-dimensional labeled array capable of holding any data type. The axis labels are collectively called the index.

# %% [markdown]
# #### Creating Series
# ##### There are multiple ways to create a pandas Series:

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
# Installing collected packages: pandas
# Successfully installed pandas-3.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
