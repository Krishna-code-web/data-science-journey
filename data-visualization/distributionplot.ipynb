# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.1)
# Requirement already satisfied: pillow>=8 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/krishna/Desktop/Intern&Job Preparation/Data Science /myenv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'], bins=20, kde=True)
plt.subplot(1,2,2)
sns.histplot(df['tip'], bins=20, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='reg')

# %%
sns.pairplot(df, hue='size', palette='rainbow')

# %%
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip'>
